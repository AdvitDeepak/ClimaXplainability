# %%
import numpy as np

PATH = r"/home/advit/test_new2/test/2017_0.npz"

# Load the NPZ file
data = np.load(PATH)

# Print the list of arrays stored in the NPZ file
print("Arrays in the NPZ file:", data.files)

# Access and print the contents of individual arrays
for array_name in data.files:
    print(f"\nContents of {array_name}:")
    print(data[array_name].shape)
# Out:
# Arrays in the NPZ file: ['orography', 'land_sea_mask', 'lattitude', '2m_temperature', '10m_u_component_of_wind', '10m_v_component_of_wind', 'toa_incident_solar_radiation', 'total_precipitation', 'total_cloud_cover', 'geopotential_50', 'geopotential_250', 'geopotential_500', 'geopotential_600', 'geopotential_700', 'geopotential_850', 'geopotential_925', 'u_component_of_wind_50', 'u_component_of_wind_250', 'u_component_of_wind_500', 'u_component_of_wind_600', 'u_component_of_wind_700', 'u_component_of_wind_850', 'u_component_of_wind_925', 'v_component_of_wind_50', 'v_component_of_wind_250', 'v_component_of_wind_500', 'v_component_of_wind_600', 'v_component_of_wind_700', 'v_component_of_wind_850', 'v_component_of_wind_925', 'temperature_50', 'temperature_250', 'temperature_500', 'temperature_600', 'temperature_700', 'temperature_850', 'temperature_925', 'relative_humidity_50', 'relative_humidity_250', 'relative_humidity_500', 'relative_humidity_600', 'relative_humidity_700', 'relative_h
# ...
